# %% [markdown]
# ## ЕЛЕМЕНТИ DATA CLEANING

# %% [markdown]
# ### ВАРІАНТ № 3
# ### Загальні положення

# %% [markdown]
# __Мета__:
# - Опанувати деякі методи завантаження, видобутоку та очищення первинних даних
# - Застосувати на практиці набуті знання та навички програмування на Python, а саме:
#     - читання і запис даних у файли;
#     - організація циклічної оброобки даних (for .. in ..)
#     - реалізація умовної обробки (if .. elif .. else)
#     - використання методів і функцій стандартної бібліотеки Python
#
# __Вхідні дані__ : файл __aprts_data_raw.csv__, якій отримано з ресурсу _https://flatfy.lun.ua/продажа-квартир-киев_ шляхом його парсингу.
#
# Файл має наступну структуру:
#
# |    | Назва поля      | Очікуваний формат поля   |
# | -- | :-----------     | :-------------------------|
# |  1 | Ціна квартири (\$ або грн)    | дробове                  |
# |  2 | Кількість кімнат | ціле
# |  3 | Ціна за м² (\$ або грн)     | дробове
# |  4 | Поверх та всього поверхів | ціле
# | 5  | рік побудови   | ціле
# | 6  | тип будинку    | текст
# | 7  | Площа (загальна/житлова/кухні)| дробове
# | 8  | вулиця         | текст
# | 9  | номер дому     | текст
#
# __Особливі умови__: в первиних даних деякі показники можуть бути відстутні (не распарсені) - тоді вони позначаються `*** not found`

# %% [markdown]
# ### Теоретична частина та приклади

# %% [markdown]
# Вхідний файл треба зчитувати і обробляти __порядково__ -  це гарна практика роботи з великими об\`ємами даних.
#
# Дані, що зчитуються з файлів порядково представляються у текстовому (__str__) форматі, тому доцільно використовувати [функції обробки строкових даних](https://pythonworld.ru/tipy-dannyx-v-python/stroki-funkcii-i-metody-strok.html) python:

# %%
# split() - дозволяє розділити текстову строку на окремі поля і помістити їх в список

stroka = "Вася Пупкін - студент 5 курсу ФІТ"
print("Розподільник: ` `")
print (stroka)
list_from_stroka = stroka.split()
print(list_from_stroka, end='\n\n')

# якщо в якості аргумента split вказати розподільник, 
# то він буде використаний при побудові списка
list_from_stroka = stroka.split('-')
print("Розподільник: `-`")
print (stroka)
print(list_from_stroka)

# %% [markdown]
# __Примітка:__ файли в csv-форматі мають в якості розподільника, як правило, символ `,`

# %%
# за допомогою метода strip() є можливість "обрізати" зліва та справа пробіли 
# (якщо параметер не вказано), або символи, які вказані в якостиі параметрів:

stroka = "     Вася Пупкін - студент 5 курсу ФІТ   "
striped_stroka = stroka.strip()
print(stroka)
print(striped_stroka)
print(striped_stroka.strip('ФІТ'))

# %% [markdown]
# __Конвертування строкових даних__ у чисельні здійснюється за допомогою функцій [int](https://pythoner.name/int-function) або [float](https://www.programiz.com/python-programming/methods/built-in/float), але треба мати на увазі що ці функціі викинуть виключення, якщо буде спроба конвертувати не число. Тому перед виконанням конвертування доцільно перевіряти, чи буде воно успішнім. Для цього можна викорастати функцію [isnumeric](https://pythonz.net/references/named/str.isnumeric/).

# %%
# 
number_str = '123.3'
print(type(number_str))
number_float = float(number_str)
print(type(number_float), end='\n\n')

# але
maybe_number_str = '123.З' # після крапки не число!
print(type(number_str))
# number_float = float(maybe_number_str) # ValueError: could not convert string to float: '123.З'

# треба
if maybe_number_str.isnumeric():
    #  True
    number_float = float(maybe_number_str)
else:
    # False
    # код який обробляє цю ситуацію
    ...

# %% [markdown]
# ### Приклад розбору рядків, та вилучення показчиків

# %%
# Припустимо, що ми маємо файл, вміст якого відображається на список:
file_content = [
    'Вася Пупкін ,  5 курс, ФІТ',
    'Петя Сидоров, 1 курс, ФТМ',
    ' Вова   Хлопов , 3 курс, ФІТ'
]
_ = [print(x) for x in file_content]

# %%
# треба створити новий список, який буде містити окремо ім'я та прізвище

# зарезервуєм пустий контейнер
name_and_surname = []

for line in file_content:
    list_from_line = line.split(',')
    name, surname = list_from_line[0].split()
    name_and_surname += [[name.strip(), surname.strip()]]

_ = [print(x) for x in name_and_surname]

# %%
# теж саме в функціональному стилі 
from functools import reduce
reduce(lambda acc, line: acc + [line.split(',')[0].split()], file_content, [])

# %% [markdown]
# ### ЗАВДАННЯ
#
# <p style="background-color: grey; padding:10px">На основі вхідного файлу <b>aprts_data_raw.csv</b> побудувати вихідний файл <b>aprt_rooms.txt</b> кожний рядок якого є вилучене з 3 показника та приведене до очікуваного формату  значення ціни 1 м<sup>2</sup> в $.<br><br><i>При неможливості приведення показчика його треба замінити на 0</i></p>

# %% [markdown]
# _Фрагмент_ результатного файлу:
#
# `
# 1575.0
# 680.0
# 1400.0
# 2414.0
# ...
# `

# %%
import csv
with open("aprts_data_raw.csv ", encoding='utf-8') as file, \
     open('aprt_prices.txt', 'w', encoding='utf-8') as file2:
    file_read = csv.reader(file, delimiter = ",")
    count = 0
    for line in file_read:
        if line[2] == '*** not exist ':
            line[2] = '0'
            print(f'Cost: {line[2].strip()}.')
            file2.write(f'Cost: {line[2]} . \n')
        else:
            print(f'Cost: {line[2]} .')
            file2.write(f'Cost: {line[2]} . \n')
    count += 1
# Out:
# Cost: 1575 $ за м² .
# Cost: 680 $ за м² .
# Cost: 1400 $ за м² .
# Cost: 2414 $ за м² .
# Cost: 2025 $ за м² .
# Cost: 6273 $ за м² .
# Cost: 73 902 грн за м² .
# Cost: 2529 $ за м² .
# Cost: 3325 $ за м² .
# Cost: 1353 $ за м² .
# Cost: 3542 $ за м² .
# Cost: 2494 $ за м² .
# Cost: 1099 $ за м² .
# Cost: 1339 $ за м² .
# Cost: 1711 $ за м² .
# Cost: 1171 $ за м² .
# Cost: 2010 $ за м² .
# Cost: 921 $ за м² .
# Cost: 841 $ за м² .
# Cost: 1203 $ за м² .
# Cost: 1900 $ за м² .
# Cost: 781 $ за м² .
# Cost: 990 $ за м² .
# Cost: 1019 $ за м² .
# Cost: 875 $ за м² .
# Cost: 1100 $ за м² .
# Cost: 1121 $ за м² .
# Cost: 27 503 грн за м² .
# Cost: 1587 $ за м² .
# Cost: 2692 $ за м² .
# Cost: 2460 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 1556 $ за м² .
# Cost: 1773 $ за м² .
# Cost: 1001 $ за м² .
# Cost: 1481 $ за м² .
# Cost: 1778 $ за м² .
# Cost: 58 042 грн за м² .
# Cost: 1985 $ за м² .
# Cost: 2720 $ за м² .
# Cost: 934 $ за м² .
# Cost: 2384 $ за м² .
# Cost: 1768 $ за м² .
# Cost: 602 $ за м² .
# Cost: 1322 $ за м² .
# Cost: 890 $ за м² .
# Cost: 54 774 грн за м² .
# Cost: 907 $ за м² .
# Cost: 2697 $ за м² .
# Cost: 1005 $ за м² .
# Cost: 1106 $ за м² .
# Cost: 47 556 грн за м² .
# Cost: 2500 $ за м² .
# Cost: 1068 $ за м² .
# Cost: 1091 $ за м² .
# Cost: 1078 $ за м² .
# Cost: 1091 $ за м² .
# Cost: 2582 $ за м² .
# Cost: 1464 $ за м² .
# Cost: 2554 $ за м² .
# Cost: 966 $ за м² .
# Cost: 5000 $ за м² .
# Cost: 1146 $ за м² .
# Cost: 2295 $ за м² .
# Cost: 1500 $ за м² .
# Cost: 960 $ за м² .
# Cost: 1588 $ за м² .
# Cost: 1609 $ за м² .
# Cost: 1300 $ за м² .
# Cost: 1111 $ за м² .
# Cost: 2400 $ за м² .
# Cost: 1113 $ за м² .
# Cost: 2697 $ за м² .
# Cost: 1005 $ за м² .
# Cost: 1106 $ за м² .
# Cost: 47 556 грн за м² .
# Cost: 2500 $ за м² .
# Cost: 1068 $ за м² .
# Cost: 1091 $ за м² .
# Cost: 1078 $ за м² .
# Cost: 1091 $ за м² .
# Cost: 2582 $ за м² .
# Cost: 1464 $ за м² .
# Cost: 2554 $ за м² .
# Cost: 966 $ за м² .
# Cost: 5000 $ за м² .
# Cost: 1146 $ за м² .
# Cost: 2295 $ за м² .
# Cost: 1500 $ за м² .
# Cost: 960 $ за м² .
# Cost: 1588 $ за м² .
# Cost: 1609 $ за м² .
# Cost: 1300 $ за м² .
# Cost: 1111 $ за м² .
# Cost: 2400 $ за м² .
# Cost: 1113 $ за м² .
# Cost: 1667 $ за м² .
# Cost: 1290 $ за м² .
# Cost: 4717 $ за м² .
# Cost: 987 $ за м² .
# Cost: 1120 $ за м² .
# Cost: 966 $ за м² .
# Cost: 1084 $ за м² .
# Cost: 2708 $ за м² .
# Cost: 1556 $ за м² .
# Cost: 1800 $ за м² .
# Cost: 1085 $ за м² .
# Cost: 1901 $ за м² .
# Cost: 1488 $ за м² .
# Cost: 1057 $ за м² .
# Cost: 1149 $ за м² .
# Cost: 1728 $ за м² .
# Cost: 1058 $ за м² .
# Cost: 753 $ за м² .
# Cost: 2065 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 1374 $ за м² .
# Cost: 1605 $ за м² .
# Cost: 1727 $ за м² .
# Cost: 1341 $ за м² .
# Cost: 1915 $ за м² .
# Cost: 2439 $ за м² .
# Cost: 1409 $ за м² .
# Cost: 3900 $ за м² .
# Cost: 1587 $ за м² .
# Cost: 4457 $ за м² .
# Cost: 1550 $ за м² .
# Cost: 1939 $ за м² .
# Cost: 1901 $ за м² .
# Cost: 1545 $ за м² .
# Cost: 1566 $ за м² .
# Cost: 2055 $ за м² .
# Cost: 1097 $ за м² .
# Cost: 1046 $ за м² .
# Cost: 1384 $ за м² .
# Cost: 2200 $ за м² .
# Cost: 1103 $ за м² .
# Cost: 1671 $ за м² .
# Cost: 1569 $ за м² .
# Cost: 935 $ за м² .
# Cost: 1198 $ за м² .
# Cost: 2154 $ за м² .
# Cost: 2580 $ за м² .
# Cost: 1439 $ за м² .
# Cost: 2220 $ за м² .
# Cost: 1796 $ за м² .
# Cost: 819 $ за м² .
# Cost: 2283 $ за м² .
# Cost: 1398 $ за м² .
# Cost: 1233 $ за м² .
# Cost: 2414 $ за м² .
# Cost: 1233 $ за м² .
# Cost: 1353 $ за м² .
# Cost: 1340 $ за м² .
# Cost: 1730 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 55 472 грн за м² .
# Cost: 1389 $ за м² .
# Cost: 2680 $ за м² .
# Cost: 1269 $ за м² .
# Cost: 2894 $ за м² .
# Cost: 1145 $ за м² .
# Cost: 1556 $ за м² .
# Cost: 31 530 грн за м² .
# Cost: 30 000 грн за м² .
# Cost: 1571 $ за м² .
# Cost: 892 $ за м² .
# Cost: 2623 $ за м² .
# Cost: 1449 $ за м² .
# Cost: 2697 $ за м² .
# Cost: 3125 $ за м² .
# Cost: 1274 $ за м² .
# Cost: 1563 $ за м² .
# Cost: 1603 $ за м² .
# Cost: 1152 $ за м² .
# Cost: 1318 $ за м² .
# Cost: 2120 $ за м² .
# Cost: 1933 $ за м² .
# Cost: 1235 $ за м² .
# Cost: 854 $ за м² .
# Cost: 1947 $ за м² .
# Cost: 2708 $ за м² .
# Cost: 4176 $ за м² .
# Cost: 3021 $ за м² .
# Cost: 1560 $ за м² .
# Cost: 5000 $ за м² .
# Cost: 1107 $ за м² .
# Cost: 869 $ за м² .
# Cost: 2560 $ за м² .
# Cost: 2465 $ за м² .
# Cost: 25 808 грн за м² .
# Cost: 1324 $ за м² .
# Cost: 2227 $ за м² .
# Cost: 2854 $ за м² .
# Cost: 978 $ за м² .
# Cost: 31 537 грн за м² .
# Cost: 2163 $ за м² .
# Cost: 2333 $ за м² .
# Cost: 1099 $ за м² .
# Cost: 2343 $ за м² .
# Cost: 1562 $ за м² .
# Cost: 1589 $ за м² .
# Cost: 3447 $ за м² .
# Cost: 3605 $ за м² .
# Cost: 1544 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 878 $ за м² .
# Cost: 1710 $ за м² .
# Cost: 1429 $ за м² .
# Cost: 930 $ за м² .
# Cost: 3429 $ за м² .
# Cost: 3189 $ за м² .
# Cost: 1285 $ за м² .
# Cost: 2222 $ за м² .
# Cost: 1788 $ за м² .
# Cost: *** not found  .
# Cost: 733 $ за м² .
# Cost: 1100 $ за м² .
# Cost: 2011 $ за м² .
# Cost: 1055 $ за м² .
# Cost: 1315 $ за м² .
# Cost: 888 $ за м² .
# Cost: 1214 $ за м² .
# Cost: 1900 $ за м² .
# Cost: 966 $ за м² .
# Cost: 1454 $ за м² .
# Cost: 3535 $ за м² .
# Cost: 1278 $ за м² .
# Cost: 1518 $ за м² .
# Cost: 1796 $ за м² .
# Cost: 1127 $ за м² .
# Cost: 1728 $ за м² .
# Cost: 1364 $ за м² .
# Cost: 2316 $ за м² .
# Cost: 1344 $ за м² .
# Cost: 1284 $ за м² .
# Cost: 1713 $ за м² .
# Cost: 764 $ за м² .
# Cost: 1420 $ за м² .
# Cost: 1086 $ за м² .
# Cost: 2000 $ за м² .
# Cost: 1379 $ за м² .
# Cost: 2360 $ за м² .
# Cost: 812 $ за м² .
# Cost: 1426 $ за м² .
# Cost: 1116 $ за м² .
# Cost: 1085 $ за м² .
# Cost: 4405 $ за м² .
# Cost: 1243 $ за м² .
# Cost: 991 $ за м² .
# Cost: 2303 $ за м² .
# Cost: 915 $ за м² .
# Cost: 50 580 грн за м² .
# Cost: 1957 $ за м² .
# Cost: 1258 $ за м² .
# Cost: 2400 $ за м² .
# Cost: 833 $ за м² .
# Cost: 2333 $ за м² .
# Cost: 935 $ за м² .
# Cost: 2400 $ за м² .
# Cost: 1692 $ за м² .
# Cost: 2271 $ за м² .
# Cost: 1032 $ за м² .
# Cost: 2162 $ за м² .
# Cost: 1140 $ за м² .
# Cost: 925 $ за м² .
# Cost: 2818 $ за м² .
# Cost: 4412 $ за м² .
# Cost: 1574 $ за м² .
# Cost: 1220 $ за м² .
# Cost: 1045 $ за м² .
# Cost: 1830 $ за м² .
# Cost: 933 $ за м² .
# Cost: 1164 $ за м² .
# Cost: 2038 $ за м² .
# Cost: 1113 $ за м² .
# Cost: 1402 $ за м² .
# Cost: 1798 $ за м² .
# Cost: 1460 $ за м² .
# Cost: 1100 $ за м² .
# Cost: 1829 $ за м² .
# Cost: 1480 $ за м² .
# Cost: 760 $ за м² .
# Cost: 1589 $ за м² .
# Cost: 1488 $ за м² .
# Cost: 3151 $ за м² .
# Cost: 2279 $ за м² .
# Cost: 1455 $ за м² .
# Cost: 1190 $ за м² .
# Cost: 1398 $ за м² .
# Cost: 1522 $ за м² .
# Cost: *** not found  .
# Cost: 937 $ за м² .
# Cost: 982 $ за м² .
# Cost: 1175 $ за м² .
# Cost: 2043 $ за м² .
# Cost: 710 $ за м² .
# Cost: *** not found  .
# Cost: 4601 $ за м² .
# Cost: 1097 $ за м² .
# Cost: 1127 $ за м² .
# Cost: 2111 $ за м² .
# Cost: *** not found  .
# Cost: 1575 $ за м² .
# Cost: 1324 $ за м² .
# Cost: 1140 $ за м² .
# Cost: 1167 $ за м² .
# Cost: 4727 $ за м² .
# Cost: 1379 $ за м² .
# Cost: *** not found  .
# Cost: 1500 $ за м² .
# Cost: 1544 $ за м² .
# Cost: 27 900 грн за м² .
# Cost: 1369 $ за м² .
# Cost: 2759 $ за м² .
# Cost: 1724 $ за м² .
# Cost: 809 $ за м² .
# Cost: 1043 $ за м² .
# Cost: 2045 $ за м² .
# Cost: 1158 € за м² .
# Cost: 1046 $ за м² .
# Cost: 1741 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 2086 $ за м² .
# Cost: 1692 $ за м² .
# Cost: 3166 $ за м² .
# Cost: 975 $ за м² .
# Cost: 1132 $ за м² .
# Cost: 1020 $ за м² .
# Cost: 1560 $ за м² .
# Cost: 1071 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 6000 $ за м² .
# Cost: 1288 $ за м² .
# Cost: 1009 $ за м² .
# Cost: 3038 $ за м² .
# Cost: 2214 $ за м² .
# Cost: 1400 $ за м² .
# Cost: 936 $ за м² .
# Cost: 1566 $ за м² .
# Cost: 3846 $ за м² .
# Cost: 3425 $ за м² .
# Cost: 812 $ за м² .
# Cost: *** not found  .
# Cost: 3333 $ за м² .
# Cost: 1018 $ за м² .
# Cost: 1292 $ за м² .
# Cost: 1702 $ за м² .
# Cost: 2097 $ за м² .
# Cost: *** not found  .
# Cost: 1842 $ за м² .
# Cost: 52 688 грн за м² .
# Cost: 1000 $ за м² .
# Cost: 827 $ за м² .
# Cost: *** not found  .
# Cost: 1683 $ за м² .
# Cost: 1415 $ за м² .
# Cost: 2013 $ за м² .
# Cost: 2200 $ за м² .
# Cost: 936 $ за м² .
# Cost: 1274 $ за м² .
# Cost: *** not found  .
# Cost: 4487 $ за м² .
# Cost: 1080 $ за м² .
# Cost: 2724 $ за м² .
# Cost: 3580 $ за м² .
# Cost: 2080 $ за м² .
# Cost: 1209 $ за м² .
# Cost: 3038 $ за м² .
# Cost: 2450 $ за м² .
# Cost: 3606 $ за м² .
# Cost: 2124 $ за м² .
# Cost: 1389 $ за м² .
# Cost: 1429 $ за м² .
# Cost: 1361 $ за м² .
# Cost: 1826 $ за м² .
# Cost: 1925 $ за м² .
# Cost: 1348 $ за м² .
# Cost: 1442 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 1500 $ за м² .
# Cost: 2000 $ за м² .
# Cost: 918 $ за м² .
# Cost: 1157 $ за м² .
# Cost: 1326 $ за м² .
# Cost: 958 $ за м² .
# Cost: 2202 $ за м² .
# Cost: 1015 $ за м² .
# Cost: 1275 $ за м² .
# Cost: 5000 $ за м² .
# Cost: 1388 $ за м² .
# Cost: 1595 $ за м² .
# Cost: 1913 $ за м² .
# Cost: 2244 $ за м² .
# Cost: 2022 $ за м² .
# Cost: 1288 $ за м² .
# Cost: 1873 $ за м² .
# Cost: 2214 $ за м² .
# Cost: 2222 $ за м² .
# Cost: 1730 $ за м² .
# Cost: 1330 $ за м² .
# Cost: 3059 $ за м² .
# Cost: 1835 $ за м² .
# Cost: 1627 $ за м² .
# Cost: 1316 $ за м² .
# Cost: 2494 $ за м² .
# Cost: 1486 $ за м² .
# Cost: 1362 $ за м² .
# Cost: 3120 $ за м² .
# Cost: 1133 $ за м² .
# Cost: 1181 $ за м² .
# Cost: 2131 $ за м² .
# Cost: 1073 $ за м² .
# Cost: 3208 $ за м² .
# Cost: 2047 $ за м² .
# Cost: 892 $ за м² .
# Cost: 986 $ за м² .
# Cost: 2141 $ за м² .
# Cost: 729 $ за м² .
# Cost: 1725 $ за м² .
# Cost: 2824 $ за м² .
# Cost: 1438 $ за м² .
# Cost: 33 177 грн за м² .
# Cost: 1438 $ за м² .
# Cost: 1339 $ за м² .
# Cost: 1100 $ за м² .
# Cost: 5577 $ за м² .
# Cost: 1630 $ за м² .
# Cost: 2903 $ за м² .
# Cost: 1158 $ за м² .
# Cost: 1252 $ за м² .
# Cost: 1667 $ за м² .
# Cost: 819 $ за м² .
# Cost: 1456 $ за м² .
# Cost: 858 $ за м² .
# Cost: 913 $ за м² .
# Cost: 1153 $ за м² .
# Cost: 868 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 1355 $ за м² .
# Cost: 2073 $ за м² .
# Cost: 1286 $ за м² .
# Cost: 915 $ за м² .
# Cost: 1033 $ за м² .
# Cost: 828 $ за м² .
# Cost: 1384 $ за м² .
# Cost: 1960 $ за м² .
# Cost: 1925 $ за м² .
# Cost: 2924 $ за м² .
# Cost: 884 $ за м² .
# Cost: 2708 $ за м² .
# Cost: 2644 $ за м² .
# Cost: 1260 $ за м² .
# Cost: 1488 $ за м² .
# Cost: 2457 $ за м² .
# Cost: 1788 $ за м² .
# Cost: 4637 $ за м² .
# Cost: 1238 $ за м² .
# Cost: 1500 $ за м² .
# Cost: 2273 $ за м² .
# Cost: 1268 $ за м² .
# Cost: 2400 $ за м² .
# Cost: 1397 $ за м² .
# Cost: 951 $ за м² .
# Cost: 2500 $ за м² .
# Cost: 2270 $ за м² .
# Cost: 3083 $ за м² .
# Cost: *** not found  .
# Cost: 717 $ за м² .
# Cost: 4601 $ за м² .
# Cost: 2442 $ за м² .
# Cost: 887 $ за м² .
# Cost: 1264 $ за м² .
# Cost: *** not found  .
# Cost: 1602 $ за м² .
# Cost: 1157 $ за м² .
# Cost: 879 $ за м² .
# Cost: 1797 $ за м² .
# Cost: *** not found  .
# Cost: 1649 $ за м² .
# Cost: 1982 $ за м² .
# Cost: 2065 $ за м² .
# Cost: 2875 $ за м² .
# Cost: 25 000 грн за м² .
# Cost: 2857 $ за м² .
# Cost: *** not found  .
# Cost: 2125 $ за м² .
# Cost: 1329 $ за м² .
# Cost: 1058 $ за м² .
# Cost: 926 $ за м² .
# Cost: 1558 $ за м² .
# Cost: 3024 $ за м² .
# Cost: 1634 $ за м² .
# Cost: 2568 $ за м² .
# Cost: 787 $ за м² .
# Cost: 1899 $ за м² .
# Cost: 1100 $ за м² .
# Cost: 1291 $ за м² .
# Cost: 1418 $ за м² .
# Cost: 1714 $ за м² .
# Cost: 3807 $ за м² .
# Cost: 1604 $ за м² .
# Cost: 1098 $ за м² .
# Cost: 1092 $ за м² .
# Cost: 3543 $ за м² .
# Cost: 6000 $ за м² .
# Cost: 1324 $ за м² .
# Cost: 1961 $ за м² .
# Cost: 2131 $ за м² .
# Cost: 24 436 грн за м² .
# Cost: 822 $ за м² .
# Cost: 1215 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 2647 $ за м² .
# Cost: 1998 $ за м² .
# Cost: 1556 $ за м² .
# Cost: 1280 $ за м² .
# Cost: 2214 $ за м² .
# Cost: 1384 $ за м² .
# Cost: 1750 $ за м² .
# Cost: 2750 $ за м² .
# Cost: 2685 $ за м² .
# Cost: 2857 $ за м² .
# Cost: 1459 $ за м² .
# Cost: 1036 $ за м² .
# Cost: 534 $ за м² .
# Cost: 4455 $ за м² .
# Cost: 875 $ за м² .
# Cost: 1885 $ за м² .
# Cost: 878 $ за м² .
# Cost: 2965 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 1188 $ за м² .
# Cost: 1795 $ за м² .
# Cost: 1985 $ за м² .
# Cost: 1163 $ за м² .
# Cost: 1426 $ за м² .
# Cost: 1941 $ за м² .
# Cost: 1286 $ за м² .
# Cost: 2434 $ за м² .
# Cost: 2824 $ за м² .
# Cost: 2500 $ за м² .
# Cost: 1055 $ за м² .
# Cost: 6522 $ за м² .
# Cost: 2220 $ за м² .
# Cost: 1544 $ за м² .
# Cost: 1732 $ за м² .
# Cost: 1715 $ за м² .
# Cost: 1138 $ за м² .
# Cost: 3731 $ за м² .
# Cost: 882 $ за м² .
# Cost: 38 182 грн за м² .
# Cost: 24 979 грн за м² .
# Cost: 852 $ за м² .
# Cost: 2355 $ за м² .
# Cost: 2300 $ за м² .
# Cost: 2104 $ за м² .
# Cost: 976 $ за м² .
# Cost: 1554 $ за м² .
# Cost: 920 $ за м² .
# Cost: 2121 $ за м² .
# Cost: 34 954 грн за м² .
# Cost: 1388 $ за м² .
# Cost: 1455 $ за м² .
# Cost: 2667 $ за м² .
# Cost: 2246 $ за м² .
# Cost: 1960 $ за м² .
# Cost: 1562 $ за м² .
# Cost: 1136 $ за м² .
# Cost: 1721 $ за м² .
# Cost: 2244 $ за м² .
# Cost: 1707 $ за м² .
# Cost: 2091 $ за м² .
# Cost: 1364 $ за м² .
# Cost: 2068 $ за м² .
# Cost: 2683 $ за м² .
# Cost: 1405 $ за м² .
# Cost: 2377 $ за м² .
# Cost: 988 $ за м² .
# Cost: 3151 $ за м² .
# Cost: 2302 $ за м² .
# Cost: 4048 $ за м² .
# Cost: 1977 $ за м² .
# Cost: 2800 $ за м² .
# Cost: 3792 $ за м² .
# Cost: 1528 $ за м² .
# Cost: 1064 $ за м² .
# Cost: 1696 $ за м² .
# Cost: 1131 $ за м² .
# Cost: 1273 $ за м² .
# Cost: 1152 $ за м² .
# Cost: *** not found  .
# Cost: 1237 $ за м² .
# Cost: 1967 $ за м² .
# Cost: 2889 $ за м² .
# Cost: 2309 $ за м² .
# Cost: 1000 $ за м² .
# Cost: *** not found  .
# Cost: 10 000 $ за м² .
# Cost: 1085 $ за м² .
# Cost: 2660 $ за м² .
# Cost: 927 $ за м² .
# Cost: *** not found  .
# Cost: 1000 $ за м² .
# Cost: 1719 $ за м² .
# Cost: 1500 $ за м² .
# Cost: 2300 $ за м² .
# Cost: 1250 $ за м² .
# Cost: 2429 $ за м² .
# Cost: *** not found  .
# Cost: 1690 $ за м² .
# Cost: 2121 $ за м² .
# Cost: 2563 $ за м² .
# Cost: 1718 $ за м² .
# Cost: 1441 $ за м² .
# Cost: 1124 $ за м² .
# Cost: 1115 $ за м² .
# Cost: 1071 $ за м² .
# Cost: 725 $ за м² .
# Cost: 1667 $ за м² .
# Cost: 1139 $ за м² .
# Cost: 2240 $ за м² .
# Cost: 1044 $ за м² .
# Cost: 885 $ за м² .
# Cost: 2017 $ за м² .
# Cost: 1016 $ за м² .
# Cost: 1533 $ за м² .
# Cost: 2618 $ за м² .
# Cost: 1585 $ за м² .
# Cost: 1551 $ за м² .
# Cost: 1056 $ за м² .
# Cost: 1486 $ за м² .
# Cost: 1146 $ за м² .
# Cost: 2703 $ за м² .
# Cost: 1296 $ за м² .
# Cost: 1828 $ за м² .
# Cost: 1510 $ за м² .
# Cost: 2077 $ за м² .
# Cost: 4300 $ за м² .
# Cost: 1020 $ за м² .
# Cost: 1550 $ за м² .
# Cost: 982 $ за м² .
# Cost: 1273 $ за м² .
# Cost: *** not found  .
# Cost: 973 $ за м² .
# Cost: 1036 $ за м² .
# Cost: 2152 $ за м² .
# Cost: 2015 $ за м² .
# Cost: 1650 $ за м² .
# Cost: *** not found  .
# Cost: 26 667 грн за м² .
# Cost: 796 $ за м² .
# Cost: 1550 $ за м² .
# Cost: 1569 $ за м² .
# Cost: *** not found  .
# Cost: 14 610 $ за м² .
# Cost: 1067 $ за м² .
# Cost: 2111 $ за м² .
# Cost: 3607 $ за м² .
# Cost: 1048 $ за м² .
# Cost: 1344 $ за м² .
# Cost: *** not found  .
# Cost: 1757 $ за м² .
# Cost: 1447 $ за м² .
# Cost: 2000 $ за м² .
# Cost: 1931 $ за м² .
# Cost: 1754 $ за м² .
# Cost: 3158 $ за м² .
# Cost: 2043 $ за м² .
# Cost: 921 $ за м² .
# Cost: 1742 $ за м² .
# Cost: 2375 $ за м² .
# Cost: 1586 $ за м² .
# Cost: 2412 $ за м² .
# Cost: 921 $ за м² .
# Cost: 2017 $ за м² .
# Cost: 1500 $ за м² .
# Cost: 1643 $ за м² .
# Cost: 1702 $ за м² .
# Cost: 5153 $ за м² .
# Cost: 3088 $ за м² .
# Cost: 900 $ за м² .
# Cost: 1137 $ за м² .
# Cost: 1742 $ за м² .
# Cost: 956 $ за м² .
# Cost: 999 $ за м² .
# Cost: 1947 $ за м² .
# Cost: 43 400 грн за м² .
# Cost: 1722 $ за м² .
# Cost: 935 $ за м² .
# Cost: 917 $ за м² .
# Cost: 1550 $ за м² .
# Cost: 1741 $ за м² .
# Cost: 55 506 грн за м² .
# Cost: 1242 $ за м² .
# Cost: *** not found  .
# Cost: 1071 $ за м² .
# Cost: 1333 $ за м² .
# Cost: 3430 $ за м² .
# Cost: 1247 $ за м² .
# Cost: 1490 $ за м² .
# Cost: *** not found  .
# Cost: 1500 $ за м² .
# Cost: 833 $ за м² .
# Cost: 1138 $ за м² .
# Cost: 741 $ за м² .
# Cost: *** not found  .
# Cost: 1362 $ за м² .
# Cost: 938 $ за м² .
# Cost: 903 $ за м² .
# Cost: 1609 $ за м² .
# Cost: 1084 $ за м² .
# Cost: 2446 $ за м² .
# Cost: *** not found  .
# Cost: 1893 $ за м² .
# Cost: 2656 $ за м² .
# Cost: 1167 $ за м² .
# Cost: 1719 $ за м² .
# Cost: 1757 $ за м² .
# Cost: 2222 $ за м² .
# Cost: 2778 $ за м² .
# Cost: 1548 $ за м² .
# Cost: 1374 $ за м² .
# Cost: 1536 $ за м² .
# Cost: 907 $ за м² .
# Cost: 1461 $ за м² .
# Cost: 1019 $ за м² .
# Cost: 2263 $ за м² .
# Cost: 1743 $ за м² .
# Cost: 1433 $ за м² .
# Cost: 4338 $ за м² .
# Cost: 1160 $ за м² .
# Cost: 1281 $ за м² .
# Cost: 1529 $ за м² .
# Cost: 1615 $ за м² .
# Cost: 2200 $ за м² .
# Cost: 956 $ за м² .
# Cost: 25 411 грн за м² .
# Cost: 1607 $ за м² .
# Cost: 707 $ за м² .
# Cost: 1508 $ за м² .
# Cost: 2455 $ за м² .
# Cost: 2317 $ за м² .
# Cost: 3133 $ за м² .
# Cost: 33 520 грн за м² .
# Cost: 53 000 грн за м² .
# Cost: 1039 $ за м² .
# Cost: 1677 $ за м² .
# Cost: 1364 $ за м² .
# Cost: 3021 $ за м² .
# Cost: 2041 $ за м² .
# Cost: 1771 $ за м² .
# Cost: 5500 $ за м² .
# Cost: 1106 $ за м² .
# Cost: 1252 $ за м² .
# Cost: 1429 $ за м² .
# Cost: 1250 $ за м² .
# Cost: 79 800 грн за м² .
# Cost: 1122 $ за м² .
# Cost: 1108 $ за м² .
# Cost: 1273 $ за м² .
# Cost: 926 $ за м² .
# Cost: 2195 $ за м² .
# Cost: 955 $ за м² .
# Cost: 948 $ за м² .
# Cost: 2011 $ за м² .
# Cost: 4972 $ за м² .
# Cost: 1263 $ за м² .
# Cost: 1000 $ за м² .
# Cost: 777 $ за м² .
# Cost: 1184 $ за м² .
# Cost: *** not found  .
# Cost: 1796 $ за м² .
# Cost: 1525 $ за м² .
# Cost: 914 $ за м² .
# Cost: 1602 $ за м² .
# Cost: 3810 $ за м² .
# Cost: *** not found  .
# Cost: 1833 $ за м² .
# Cost: 4167 $ за м² .
# Cost: 4000 $ за м² .
# Cost: 2188 $ за м² .
# Cost: *** not found  .
# Cost: 3000 $ за м² .
# Cost: 1663 $ за м² .
# Cost: 1955 $ за м² .
# Cost: 1147 $ за м² .
# Cost: 4893 $ за м² .
# Cost: 3056 $ за м² .
# Cost: *** not found  .
# Cost: 32 470 грн за м² .
# Cost: 2333 $ за м² .
# Cost: 1789 $ за м² .
# Cost: 1652 $ за м² .
# Cost: 2700 $ за м² .
# Cost: 2024 $ за м² .
